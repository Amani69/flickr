# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import plotly.express as px 
warnings.filterwarnings('ignore')
from nltk.tokenize import sent_tokenize
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt 
from PIL import Image
import numpy as np 
import nltk
from nltk.corpus import words
from nltk.corpus import stopwords
nltk.corpus.stopwords.words()
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
df = pd.read_csv('C:/Users/SIMPLON/Desktop/flickr/flickr_data.csv',delimiter=',', encoding='utf8', error_bad_lines=False)
# Out:
# b'Skipping line 1555: expected 16 fields, saw 17\nSkipping line 3691: expected 16 fields, saw 17\n'
# b'Skipping line 74107: expected 16 fields, saw 18\nSkipping line 74108: expected 16 fields, saw 18\nSkipping line 75320: expected 16 fields, saw 17\nSkipping line 75323: expected 16 fields, saw 17\nSkipping line 78506: expected 16 fields, saw 17\nSkipping line 78516: expected 16 fields, saw 17\nSkipping line 78517: expected 16 fields, saw 17\nSkipping line 78518: expected 16 fields, saw 17\nSkipping line 78519: expected 16 fields, saw 17\nSkipping line 78520: expected 16 fields, saw 17\nSkipping line 80008: expected 16 fields, saw 17\nSkipping line 81821: expected 16 fields, saw 17\n'

# %%
df.columns=[col.replace(' ','') for col in df.columns]

# %%
df2=df.drop_duplicates()
df2=df2.dropna()

# %%
import spacy
import fr_core_news_sm
nlp = spacy.load("fr_core_news_sm")

# %%
text=' '.join(df2["tags"]).strip().replace(",",'')
text
# Out:
# 'squaresierrasquareformatiphoneographyinstagramappuploaded:by=instagramfoursquare:venue=4e0462c82271233b767cec75 squaresquareformatiphoneographyinstagramappuploaded:by=instagram sunsetskycloudsunsoleilcoucherdesoleil francearchitecturelyonofficesappartmentsincityalbertconstantinvalodepistrejeanzumbrunnendenisvalodemarcelgutjeansillanmonceynord squaresquareformatiphoneographyinstagramappuploaded:by=instagram franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornithologie franceanimauxfroiseaurhonegierrhônealpesgivorsornitholog
# ...

# %%
#Content-related
stopwords = set(STOPWORDS)

#Appearance-related
custom_mask = np.array(Image.open('Capture.png')) 
wc = WordCloud(background_color = 'white',
               stopwords = stopwords,
               mask = custom_mask,
               contour_width = 3,
               contour_color = 'black')

wc.generate(text)
image_colors = ImageColorGenerator(custom_mask)
wc.recolor(color_func = image_colors)
#Plotting
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
custom_mask = np.array(Image.open('Capture.PNG')) 
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text2=' '.join(df2["title"]).strip().replace("#",'')
text2
# Out:
# 'Enfin. instabeer beer chimay apero https://www.facebook.com/PascalFrontiPhotographie/photos/a.400754443288716.92556.400751579955669/1039351156095705/?type=3&theater hommage solidarité solidarité fetedeslumieres follow followme follow4follow followforfollow instagrammers instalyon Un soir dans les Monts du Lyonnais InCity, Lyon, France, 2015 @Bidule_officiel C\'est à la Renaissance que l\'on a inventé métro londonien. It is in the Renaissance that we invented the londonian underground. www.monsieurbidule.net  igers igersart igersparis igersstreet igersstreetart paris streetart spaceinva Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalacrocorax carbo) Martin-pêcheur d\'Europe (Alcedo atthis) Martin-pêcheur d\'Europe (Alcedo atthis) Martin-pêcheur d\'Europe (Alcedo atthis) Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalacrocorax carbo) Grand Cormoran (Phalac
# ...

# %%
word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

# %%
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Nettoyage

# %%
from spacy.lang.fr.stop_words import STOP_WORDS

# %%
# importing NLTK libarary stopwords 
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
print(stopwords.words('french'))
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'a
# ...

# %% [markdown]
# # word_tokenize for title

# %%
sample_text = text2.replace(r'[-./?!,":;()\']',' ')
text_tokens = word_tokenize(sample_text)

tokens_without_sw = [word for word in text_tokens if  word not  in stopwords.words('french')]

#print(tokens_without_sw)

# %%
filtered_words = [word for word in tokens_without_sw if word not in stopwords.words('english')]

# %%
#filtered_words

# %%
import re
sp_pattern = re.compile( """[\.\!\"\s\?\-\,\)\(\']+""", re.M).split
sp_pattern(str(filtered_words))
# Out:
# ['[',
#  'Enfin',
#  'instabeer',
#  'beer',
#  'chimay',
#  'apero',
#  'https',
#  ':',
#  '//www',
#  'facebook',
#  'com/PascalFrontiPhotographie/photos/a',
#  '400754443288716',
#  '92556',
#  '400751579955669/1039351156095705/',
#  'type=3',
#  '&',
#  'theater',
#  'hommage',
#  'solidarité',
#  'solidarité',
#  'fetedeslumieres',
#  'follow',
#  'followme',
#  'follow4follow',
#  'followforfollow',
#  'instagrammers',
#  'instalyon',
#  'Un',
#  'soir',
#  'Monts',
#  'Lyonnais',
#  'InCity',
#  'Lyon',
#  'France',
#  '2015',
#  '@',
#  'Bidule_officiel',
#  'C',
#  'est',
#  'Renaissance',
#  'l',
#  'on',
#  'inventé',
#  'métro',
#  'londonien',
#  'It',
#  'Renaissance',
#  'invented',
#  'londonian',
#  'underground',
#  'www',
#  'monsieurbidule',
#  'net',
#  'igers',
#  'igersart',
#  'igersparis',
#  'igersstreet',
#  'igersstreetart',
#  'paris',
#  'streetart',
#  'spaceinva',
#  'Grand',
#  'Cormoran',
#  'Phalacrocorax',
#  'carbo',
#  'Grand',
#  'Cormoran',
# ...

# %%
from nltk.tokenize import sent_tokenize
text21=sent_tokenize(str(filtered_words))

# %%
word_cloud21 = WordCloud(collocations = False, background_color = 'white').generate(str(filtered_words))
plt.imshow(word_cloud21, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
fd = nltk.FreqDist(text21) 
print(fd.most_common())
# Out:
# [("', '!", 42), ("', 'Eglise', 'Saint-Bruno', 'Chartreux', 'Lyon', '.", 15), ("', '?", 14), ('\', \'Basilique\', \'Saint-Martin\', "d\'Ainay", \',\', "presqu\'île", \'Lyon\', \',\', \'2e\', \'.', 11), ("', 'Les', 'traboules', 'Lyon', '.", 10), ("', 'Les', 'traboules', ',', 'Maison', 'Chamarier', 'Lyon', '.", 9), ("', 'Musée', 'Confluences', ',', 'Lyon', '.", 4), ("', 'Amphithéâtre', 'Trois', 'Gaules', 'Lyon', '.", 4), ("', 'Faisan', 'urbain', '........', '!", 3), ('\', \'Nouvelle\', \'collection\', \'[\', \'AË\', \']\', \'E\', \'DANS\', \'L\', "\'", \'A\', \'marque\', \'prêt-à-porter\', \'toutes\', \'ptites\', \'pépés\', \'!', 2), ("', '.", 2), ("', 'Ça', 'pique', '!", 2), ('\', \'Xavier\', \'Privas\', \'monument\', \'\\\\Le\', \'Jardin\', \'Chartreux\\\\\', "\'\'", "\'\'", \'Lyon\', \'.', 2), ("['Enfin', '.", 1), ("', 'instabeer', 'beer', 'chimay', 'apero', 'https', ':', '//www.facebook.com/PascalFrontiPhotographie/photos/a.400754443288716.92556.400751579955669/1039351156095705/', '
# ...

# %%
import gensim
from gensim.parsing.preprocessing import remove_stopwords
sample_text_NSW = remove_stopwords(str(text21))

# %%
sp_pattern = re.compile( """[\.\!\"\s\?\-\,\\\\(\)\@\d\']+""", re.M).split
sp_pattern(str(sample_text_NSW ))
# Out:
# ['[',
#  '[',
#  'Enfin',
#  'instabeer',
#  'beer',
#  'chimay',
#  'apero',
#  'https',
#  ':',
#  '//www',
#  'facebook',
#  'com/PascalFrontiPhotographie/photos/a',
#  '/',
#  '/',
#  'type=',
#  '&',
#  'theater',
#  'hommage',
#  'solidarité',
#  'solidarité',
#  'fetedeslumieres',
#  'follow',
#  'followme',
#  'follow',
#  'follow',
#  'followforfollow',
#  'instagrammers',
#  'instalyon',
#  'Un',
#  'soir',
#  'Monts',
#  'Lyonnais',
#  'InCity',
#  'Lyon',
#  'France',
#  'Bidule_officiel',
#  'C',
#  'est',
#  'Renaissance',
#  'l',
#  'on',
#  'inventé',
#  'métro',
#  'londonien',
#  'It',
#  'Renaissance',
#  'invented',
#  'londonian',
#  'underground',
#  'www',
#  'monsieurbidule',
#  'net',
#  'igers',
#  'igersart',
#  'igersparis',
#  'igersstreet',
#  'igersstreetart',
#  'paris',
#  'streetart',
#  'spaceinva',
#  'Grand',
#  'Cormoran',
#  'Phalacrocorax',
#  'carbo',
#  'Grand',
#  'Cormoran',
#  'Phalacrocorax',
#  'carbo',
#  'Martin',
#  'pêcheur',
# ...

# %%
word_cloud21 = WordCloud(collocations = False, background_color = 'white').generate(str(sample_text_NSW ))
plt.imshow(word_cloud21, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_sans_chiffre = ''.join([i for i in str(sample_text_NSW ) if not i.isdigit()])
print(text_sans_chiffre)
# Out:
# ["['Enfin', '.", "', 'instabeer', 'beer', 'chimay', 'apero', 'https', ':', '//www.facebook.com/PascalFrontiPhotographie/photos/a...//', '?", '\', \'type=\', \'&\', \'theater\', \'hommage\', \'solidarité\', \'solidarité\', \'fetedeslumieres\', \'follow\', \'followme\', \'followfollow\', \'followforfollow\', \'instagrammers\', \'instalyon\', \'Un\', \'soir\', \'Monts\', \'Lyonnais\', \'InCity\', \',\', \'Lyon\', \',\', \'France\', \',\', \'\', \'@\', \'Bidule_officiel\', "C\'est", \'Renaissance\', "l\'on", \'inventé\', \'métro\', \'londonien\', \'.', "', 'It', 'Renaissance', 'invented', 'londonian', 'underground', '.", '\', \'www.monsieurbidule.net\', \'igers\', \'igersart\', \'igersparis\', \'igersstreet\', \'igersstreetart\', \'paris\', \'streetart\', \'spaceinva\', \'Grand\', \'Cormoran\', \'(\', \'Phalacrocorax\', \'carbo\', \')\', \'Grand\', \'Cormoran\', \'(\', \'Phalacrocorax\', \'carbo\', \')\', \'Martin-pêcheur\', "d\'Europe", \'(\', \'Alcedo\', \'atthis\', \')\', \'Martin-pêc
# ...

# %%
sp_pattern = re.compile( """[\.\!\"\\:\s\?\-\,\\\\(\)\@\d\']+""", re.M).split
text_sans_chiffre =sp_pattern(str(text_sans_chiffre ))

# %%
word_cloud211 = WordCloud(collocations = False, background_color = 'white').generate(str(text_sans_chiffre ))
plt.imshow(word_cloud211, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sample_text_NSW = remove_stopwords(str(text_sans_chiffre))
sample_text_NSW
# Out:
# "['[', '[', 'Enfin', 'instabeer', 'beer', 'chimay', 'apero', 'https', '//www', 'facebook', 'com/PascalFrontiPhotographie/photos/a', '//', 'type=', '&', 'theater', 'hommage', 'solidarité', 'solidarité', 'fetedeslumieres', 'follow', 'followme', 'followfollow', 'followforfollow', 'instagrammers', 'instalyon', 'Un', 'soir', 'Monts', 'Lyonnais', 'InCity', 'Lyon', 'France', 'Bidule_officiel', 'C', 'est', 'Renaissance', 'l', 'on', 'inventé', 'métro', 'londonien', 'It', 'Renaissance', 'invented', 'londonian', 'underground', 'www', 'monsieurbidule', 'net', 'igers', 'igersart', 'igersparis', 'igersstreet', 'igersstreetart', 'paris', 'streetart', 'spaceinva', 'Grand', 'Cormoran', 'Phalacrocorax', 'carbo', 'Grand', 'Cormoran', 'Phalacrocorax', 'carbo', 'Martin', 'pêcheur', 'd', 'Europe', 'Alcedo', 'atthis', 'Martin', 'pêcheur', 'd', 'Europe', 'Alcedo', 'atthis', 'Martin', 'pêcheur', 'd', 'Europe', 'Alcedo', 'atthis', 'Grand', 'Cormoran', 'Phalacrocorax', 'carbo', 'Grand', 'Cormoran', 'Phalacroco
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

stem_doc =''.join([porter.stem(word) for word in str(sample_text_NSW)])
stem_doc = nlp(stem_doc)

# %%
word_cloud2111 = WordCloud(collocations = False, background_color = 'white').generate(str(stem_doc ))
plt.imshow(word_cloud2111, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
pattern = r'[^a-zA-z0-9\s]'
data = re.sub(pattern,"", str(stem_doc ))

# %%
#data

# %%
stop_words = set(stopwords.words())
word_tokens = nltk.word_tokenize(data)
words = [w for w in word_tokens if not w in stop_words]

# %%
word_cloud21111 = WordCloud(collocations = False, background_color = 'white').generate(str(words ))
plt.imshow(word_cloud21111, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
cachedStopWords = set(stopwords.words("french"))
cachedStopWords.update(('IMG IMG','instagood pictureoftheday','europe','sane','playd','bal','lyon','sept','interdit','portrait','interdire','france','art','martin','ehrmann','place','thierry','world','img','img_','lyon_','anciennes','tte','paper','pasted','jean','rue','fte','pierre','p_','painted','saint','st','tt','ddc_','ddc','dsc','parc','matires','dimanche','upload','matin','voitures',"'",']','rhne','[','jpg',',','ddc','matin','dtails','d','D','ddc',))
#remove stop words
new_str=[word for word in words if word not in cachedStopWords]
new_str=new_str

# %%
from collections import Counter
eap_list = str(new_str).split()
eap_counts = Counter(eap_list)
eap_common_words = [word[0] for word in eap_counts.most_common(25)]
eap_common_counts = [word[1] for word in eap_counts.most_common(25)]

plt.style.use('dark_background')
plt.figure(figsize=(15, 12))

sns.barplot(x=eap_common_words, y=eap_common_counts)
plt.title('Most Common Words used by title')
# Out:
# Text(0.5, 1.0, 'Most Common Words used by title')

# %%
word_cloud21111 = WordCloud(collocations = False, background_color = 'black').generate(str(new_str))
plt.imshow(word_cloud21111, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 2eme methode

# %%
title = df2['title'].dropna()
title_list = title.tolist()
title_list = " ".join(title_list)
nlp_fr = spacy.load('fr_core_news_sm')
nlp_fr.max_length = 2914185
title_list = nlp_fr(title_list)
fr_stop = nlp_fr.Defaults.stop_words

# %%
nlp_fr.Defaults.stop_words |= set(custom_stop_words)
def make_word_cloud(doc, stopwords = None) -> None:
    mask = np.array(Image.open("lion.jpg"))
    wordcloud = WordCloud(background_color = 'white', max_words = 200, stopwords=fr_stop,mask=mask, width=1000, height=600).generate(doc.text)
    image_colors = ImageColorGenerator(mask)
    plt.figure(figsize=(15,15))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
make_word_cloud(title_list)

# %%
custom_stop_words = set(["France","FR69","Anciennes","photo","petit","IMG","IMG IMG","photograph","photographer","upload","instagood pictureoftheday","followme","instagood","pictureoftheday","Rue","Détail","serveurgroup","pentax k30","parcdesoiseaux pendaxk30","pendaxk30","salamanderspirit","nikon frankreich","leitax l35d800","leitax 135d800","leitax","k30","rhônealpes","pentax","f2 d800","f2","Aveize Auto","DMC FZ1000","FZ1000","DMC","Panasonic Lumix","Panasonic","Lumix","matières","Détails","Village","Taluyers Voitures","pentax k30","Ancienne","Taluyers","Voitures","Tôt","Pasted paper","paper","Pasted","Lyon","matin","dimanche","Voiture","uploaded","iphoneography","instagram","squareformat","instagramapp","Voiture","jpg","kenko canonef2470f28lusm", "pentaxk30","kenko","canonef2470f28lusm","nikon europe","nikon","lespritdelasalamandre serveurgroup","lespritdelasalamandre","serveurgroup","lyo15 leica","d800 leitz","d800","leitz","prophecy vanitas","prophecy","vanitas","fr","Fr","serveurgroup portrait","frankreich","prophétie","l35d800 lyo15","135d800 lyo15","lyo15","canonef2470f28lusm","canoneos1dmkiii","201511","canonef2470f28lusm","canoneos550d square","efs1855mmf3556is","canonef2470mmf28liiusm","summicron","calatrava","f2","d800","2015","leitz","rhônealpes","summicronr","summicronr35mmf2","leitax","l35d800","lyo15 leica","santiago","servergroup portrait","servergroup valencia","groupeultranationaliste portrait,""france","servergroup","groupeserveur","35mm","nikon","lyon","calatrava","summicronr35mmf2"])
